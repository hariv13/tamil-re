# %%
import pandas as pd 
from tamil import utf8
import re

# %%
data=pd.read_csv('first20000.csv') 
tamil_char=pd.read_excel('tamil_che.xlsx') # list for tamil char

# %%
data['abstract']=data['abstract'].fillna("na")
data['abstract']=data['abstract'].map(str)
abst=data['abstract'].tolist()
tamil_char=tamil_char['char'].tolist()
tamil_char.sort()

# %%
tamil_char_str="".join(tamil_char)

# %%
tamil_char_str
# Out:
# 'ஃஅஆஇஈஉஊஎஏஐஒஓஔககாகிகீகுகூகெகேகைகொகோகௌக்ஙஙாஙிஙீஙுஙூஙெஙேஙைஙொஙோஙௌங்சசாசிசீசுசூசெசேசைசொசோசௌச்ஞஞாஞிஞீஞுஞூஞெஞேஞைஞொஞோஞௌஞ்டடாடிடீடுடூடெடேடைடொடோடௌட்ணணாணிணீணுணூணெணேணைணொணோணௌண்ததாதிதீதுதூதெதேதைதொதோதௌத்நநாநிநீநுநூநெநேநைநொநோநௌந்னனானினீனுனூனெனேனைனொனோனௌன்பபாபிபீபுபூபெபேபைபொபோபௌப்மமாமிமீமுமூமெமேமைமொமோமௌம்யயாயியீயுயூயெயேயையொயோயௌய்ரராரிரீருரூரெரேரைரொரோரௌர்றறாறிறீறுறூறெறேறைறொறோறௌற்லலாலிலீலுலூலெலேலைலொலோலௌல்ளளாளிளீளுளூளெளேளைளொளோளௌள்ழழாழிழீழுழூழெழேழைழொழோழௌழ்வவாவிவீவுவூவெவேவைவொவோவௌவ்'

# %%
len(abst)
# Out:
# 20000

# %%
#creating a char2index dict
tamil_char2index={}
count=0
for i in tamil_char:
    count+=1
    tamil_char2index[i]=count

# %%
#adding numbers to the char2index dict
for i in range(0,10):
    tamil_char2index[str(i)]=250

# %%
tamil_char2index
# Out:
# {'0': 250,
#  '1': 250,
#  '2': 250,
#  '3': 250,
#  '4': 250,
#  '5': 250,
#  '6': 250,
#  '7': 250,
#  '8': 250,
#  '9': 250,
#  'ஃ': 1,
#  'அ': 2,
#  'ஆ': 3,
#  'இ': 4,
#  'ஈ': 5,
#  'உ': 6,
#  'ஊ': 7,
#  'எ': 8,
#  'ஏ': 9,
#  'ஐ': 10,
#  'ஒ': 11,
#  'ஓ': 12,
#  'ஔ': 13,
#  'க': 14,
#  'கா': 15,
#  'கி': 16,
#  'கீ': 17,
#  'கு': 18,
#  'கூ': 19,
#  'கெ': 20,
#  'கே': 21,
#  'கை': 22,
#  'கொ': 23,
#  'கோ': 24,
#  'கௌ': 25,
#  'க்': 26,
#  'ங': 27,
#  'ஙா': 28,
#  'ஙி': 29,
#  'ஙீ': 30,
#  'ஙு': 31,
#  'ஙூ': 32,
#  'ஙெ': 33,
#  'ஙே': 34,
#  'ஙை': 35,
#  'ஙொ': 36,
#  'ஙோ': 37,
#  'ஙௌ': 38,
#  'ங்': 39,
#  'ச': 40,
#  'சா': 41,
#  'சி': 42,
#  'சீ': 43,
#  'சு': 44,
#  'சூ': 45,
#  'செ': 46,
#  'சே': 47,
#  'சை': 48,
#  'சொ': 49,
#  'சோ': 50,
#  'சௌ': 51,
#  'ச்': 52,
#  'ஞ': 53,
#  'ஞா': 54,
#  'ஞி': 55,
#  'ஞீ': 56,
#  'ஞு': 57,
#  'ஞூ': 58,
#  'ஞெ': 59,
#  'ஞே': 60,
#  'ஞை': 61,
#  'ஞொ': 62,
#  'ஞோ': 63,
#  'ஞௌ': 64,
#  'ஞ்': 65,
#  'ட': 66,
#  'டா': 67,
#  'டி': 68,
#  'டீ': 69,
#  'டு': 70,
#  'டூ': 71,
#  'டெ': 72,
#  'டே': 73,
#  'டை': 74,
#  'டொ': 75,
#  'டோ': 76,
#  'டௌ': 77,
#  'ட்': 78,
#  'ண': 79,
#  'ணா': 80,
#  'ணி': 81,
#  'ணீ': 82,
#  'ணு': 83,
#  'ணூ': 84,
#  'ணெ': 85,
#  'ணே': 86,
#  'ணை': 87,
#  'ணொ': 88,
#  'ணோ': 89,
#  'ணௌ': 90,
#  'ண்': 91,
#  'த': 92,
#  'தா': 93,
#  'தி': 94,
#  'தீ': 95,
#  'து': 96,
#  'தூ': 97,
#  'தெ': 98,
#  'தே': 99,
#  'தை': 100,
#  'தொ': 101,
#  'தோ': 102,
#  'தௌ': 103,
#  'த்': 104,
#  'ந': 105,
#  'நா': 106,
#  'நி': 107,
#  'நீ': 108,
#  'நு': 109,
#  'நூ': 110,
#  'நெ': 111,
#  'நே': 112,
#  'நை': 113,
#  'நொ': 114,
#  'நோ': 115,
#  'நௌ': 116,
#  'ந்': 117,
#  'ன': 118,
#  'னா': 119,
#  'னி': 120,
#  'னீ': 121,
#  'னு': 122,
#  'னூ': 123,
#  'னெ': 124,
#  'னே': 125,
#  'னை': 126,
#  'னொ': 127,
#  'னோ': 128,
#  'னௌ': 129,
#  'ன்': 130,
#  'ப': 131,
#  'பா': 132,
#  'பி': 133,
#  'பீ': 134,
#  'பு': 135,
#  'பூ': 136,
#  'பெ': 137,
#  'பே': 138,
#  'பை': 139,
#  'பொ': 140,
#  'போ': 141,
#  'பௌ': 142,
#  'ப்': 143,
#  'ம': 144,
#  'மா': 145,
#  'மி': 146,
#  'மீ': 147,
#  'மு': 148,
#  'மூ': 149,
#  'மெ': 150,
#  'மே': 151,
#  'மை': 152,
#  'மொ': 153,
#  'மோ': 154,
#  'மௌ': 155,
#  'ம்': 156,
#  'ய': 157,
#  'யா': 158,
#  'யி': 159,
#  'யீ': 160,
#  'யு': 161,
#  'யூ': 162,
#  'யெ': 163,
#  'யே': 164,
#  'யை': 165,
#  'யொ': 166,
#  'யோ': 167,
#  'யௌ': 168,
#  'ய்': 169,
#  'ர': 170,
#  'ரா': 171,
#  'ரி': 172,
#  'ரீ': 173,
#  'ரு': 174,
#  'ரூ': 175,
#  'ரெ': 176,
#  'ரே': 177,
#  'ரை': 178,
#  'ரொ': 179,
#  'ரோ': 180,
#  'ரௌ': 181,
#  'ர்': 182,
#  'ற': 183,
#  'றா': 184,
#  'றி': 185,
#  'றீ': 186,
#  'று': 187,
#  'றூ': 188,
#  'றெ': 189,
#  'றே': 190,
#  'றை': 191,
#  'றொ': 192,
#  'றோ': 193,
#  'றௌ': 194,
#  'ற்': 195,
#  'ல': 196,
#  'லா': 197,
#  'லி': 198,
#  'லீ': 199,
#  'லு': 200,
#  'லூ': 201,
#  'லெ': 202,
#  'லே': 203,
#  'லை': 204,
#  'லொ': 205,
#  'லோ': 206,
#  'லௌ': 207,
#  'ல்': 208,
#  'ள': 209,
#  'ளா': 210,
#  'ளி': 211,
#  'ளீ': 212,
#  'ளு': 213,
#  'ளூ': 214,
#  'ளெ': 215,
#  'ளே': 216,
#  'ளை': 217,
#  'ளொ': 218,
#  'ளோ': 219,
#  'ளௌ': 220,
#  'ள்': 221,
#  'ழ': 222,
#  'ழா': 223,
#  'ழி': 224,
#  'ழீ': 225,
#  'ழு': 226,
#  'ழூ': 227,
#  'ழெ': 228,
#  'ழே': 229,
#  'ழை': 230,
#  'ழொ': 231,
#  'ழோ': 232,
#  'ழௌ': 233,
#  'ழ்': 234,
#  'வ': 235,
#  'வா': 236,
#  'வி': 237,
#  'வீ': 238,
#  'வு': 239,
#  'வூ': 240,
#  'வெ': 241,
#  'வே': 242,
#  'வை': 243,
#  'வொ': 244,
#  'வோ': 245,
#  'வௌ': 246,
#  'வ்': 247}

# %%
#joining all the various abstracts
#res = "".join(abst)

# %%
def char2wd(sentence):
    sentence=sentence.split()
    return [ch2id(word) for word in sentence]

# %%
def ch2id(word):
    letters = utf8.get_letters(word)
    temp=[]
    for letter in letters:
        if letter in tamil_char2index:
            temp.append(tamil_char2index[letter])
        else:
            temp.append(251) #251= unknown
    return temp

# %%
tamil_sa=abst[1].split()

# %%
tamil_sa
# Out:
# ['குறிப்பிடத்தக்க', 'கட்டிடக்கலைஞர்களின்', 'பட்டியல்']

# %%
ch2id(tamil_sa[1])
# Out:
# [14, 78, 68, 66, 26, 14, 204, 53, 182, 14, 211, 130]

# %%
char2wd(abst[1])
# Out:
# [[18, 185, 143, 133, 66, 104, 92, 26, 14],
#  [14, 78, 68, 66, 26, 14, 204, 53, 182, 14, 211, 130],
#  [131, 78, 68, 157, 208]]

# %%
to_clean=abst[34]

# %%
to_clean='ஆரியச் சக்கரவர்த்திகள் என்பது, இலங்கைத் தீவின் வட பாகத்திலிருந்த யாழ்ப்பாண இராச்சியத்தை 13 ஆம் நூற்றாண்டு தொடக்கம் 17ஆம் நூற்றாண்டு முற்பகுதி வரை ஆண்ட அரச வம்சத்து மன்னர்களைக் குறிக்கும். இவ்வம்சத்தின் தோற்றம் பற்றியோ இவர்கள் எங்கிருந்து வந்தார்கள் என்பது பற்றியோ எல்லோரும் ஏற்றுக்கொள்ளக்கூடிய தகவல்கள் ஏதும் இல்லை. பெரும்பாலும் இவர்கள் முதலாம் மாறவர்மன் குலசேகர பாண்டியன் என்ற பாண்டிய மன்னனின் அமைச்சர் ஆரியச் சக்கரவர்த்தி வழி வந்தவர்களே என்று கூறப்பட்டாலும்[1] மாற்றுக் கருத்துகளும் உள்ளன. இவ்வரசைத் தொடங்கிய கூழங்கைச் சக்கரவர்த்தி தென்னன் நிகரானவன் என்று போற்றப்படுவதால் இது பாண்டியர் ஆணை கீழ் நட்ந்த இராச்சியம் என்பது பெரும்பாலானோர் கருத்து.[2][3] யாழ்ப்பாணத்தின் வரலாறு பற்றிக் கூறும் வையாபாடல், யாழ்ப்பாண வைபவமாலை போன்ற நூல்கள், யாழ்ப்பாண அரசு அரசனில்லாது இருந்தபொழுது, தமிழ்நாட்டிலிருந்து அழைத்துவரப்பட்ட இளவரசனாலேயே இந்த வம்சம் ஆரம்பித்துவைக்கப் பட்டதாகக் கூறுகின்றன.'

# %%
to_clean
# Out:
# 'ஆரியச் சக்கரவர்த்திகள் என்பது, இலங்கைத் தீவின் வட பாகத்திலிருந்த யாழ்ப்பாண இராச்சியத்தை 13 ஆம் நூற்றாண்டு தொடக்கம் 17ஆம் நூற்றாண்டு முற்பகுதி வரை ஆண்ட அரச வம்சத்து மன்னர்களைக் குறிக்கும். இவ்வம்சத்தின் தோற்றம் பற்றியோ இவர்கள் எங்கிருந்து வந்தார்கள் என்பது பற்றியோ எல்லோரும் ஏற்றுக்கொள்ளக்கூடிய தகவல்கள் ஏதும் இல்லை. பெரும்பாலும் இவர்கள் முதலாம் மாறவர்மன் குலசேகர பாண்டியன் என்ற பாண்டிய மன்னனின் அமைச்சர் ஆரியச் சக்கரவர்த்தி வழி வந்தவர்களே என்று கூறப்பட்டாலும்[1] மாற்றுக் கருத்துகளும் உள்ளன. இவ்வரசைத் தொடங்கிய கூழங்கைச் சக்கரவர்த்தி தென்னன் நிகரானவன் என்று போற்றப்படுவதால் இது பாண்டியர் ஆணை கீழ் நட்ந்த இராச்சியம் என்பது பெரும்பாலானோர் கருத்து.[2][3] யாழ்ப்பாணத்தின் வரலாறு பற்றிக் கூறும் வையாபாடல், யாழ்ப்பாண வைபவமாலை போன்ற நூல்கள், யாழ்ப்பாண அரசு அரசனில்லாது இருந்தபொழுது, தமிழ்நாட்டிலிருந்து அழைத்துவரப்பட்ட இளவரசனாலேயே இந்த வம்சம் ஆரம்பித்துவைக்கப் பட்டதாகக் கூறுகின்றன.'

# %%
def tamil_rm(sentences):
    pattern = r'\(.*?\)'
    pattern1 = r'\[.*?\]'
    pattern2 = r"[A-Za-z.,]"
    #pattern3 = r"[!#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n]"
    pattern3 = r'[^ஃஅஆஇஈஉஊஎஏஐஒஓஔககாகிகீகுகூகெகேகைகொகோகௌக்ஙஙாஙிஙீஙுஙூஙெஙேஙைஙொஙோஙௌங்சசாசிசீசுசூசெசேசைசொசோசௌச்ஞஞாஞிஞீஞுஞூஞெஞேஞைஞொஞோஞௌஞ்டடாடிடீடுடூடெடேடைடொடோடௌட்ணணாணிணீணுணூணெணேணைணொணோணௌண்ததாதிதீதுதூதெதேதைதொதோதௌத்நநாநிநீநுநூநெநேநைநொநோநௌந்னனானினீனுனூனெனேனைனொனோனௌன்பபாபிபீபுபூபெபேபைபொபோபௌப்மமாமிமீமுமூமெமேமைமொமோமௌம்யயாயியீயுயூயெயேயையொயோயௌய்ரராரிரீருரூரெரேரைரொரோரௌர்றறாறிறீறுறூறெறேறைறொறோறௌற்லலாலிலீலுலூலெலேலைலொலோலௌல்ளளாளிளீளுளூளெளேளைளொளோளௌள்ழழாழிழீழுழூழெழேழைழொழோழௌழ்வவாவிவீவுவூவெவேவைவொவோவௌவ்1234567890\s\t]'
    sentences=re.sub(pattern,'', sentences)
    sentences=re.sub(pattern1,'', sentences)
    sentences=re.sub(pattern2,'', sentences)
    sentences=re.sub(pattern3,'', sentences)
    return sentences

# %%
#this cleaned version doesnot contain (.)period
tamil_rm(to_clean)
# Out:
# 'ஆரியச் சக்கரவர்த்திகள் என்பது இலங்கைத் தீவின் வட பாகத்திலிருந்த யாழ்ப்பாண இராச்சியத்தை 13 ஆம் நூற்றாண்டு தொடக்கம் 17ஆம் நூற்றாண்டு முற்பகுதி வரை ஆண்ட அரச வம்சத்து மன்னர்களைக் குறிக்கும் இவ்வம்சத்தின் தோற்றம் பற்றியோ இவர்கள் எங்கிருந்து வந்தார்கள் என்பது பற்றியோ எல்லோரும் ஏற்றுக்கொள்ளக்கூடிய தகவல்கள் ஏதும் இல்லை பெரும்பாலும் இவர்கள் முதலாம் மாறவர்மன் குலசேகர பாண்டியன் என்ற பாண்டிய மன்னனின் அமைச்சர் ஆரியச் சக்கரவர்த்தி வழி வந்தவர்களே என்று கூறப்பட்டாலும் மாற்றுக் கருத்துகளும் உள்ளன இவ்வரசைத் தொடங்கிய கூழங்கைச் சக்கரவர்த்தி தென்னன் நிகரானவன் என்று போற்றப்படுவதால் இது பாண்டியர் ஆணை கீழ் நட்ந்த இராச்சியம் என்பது பெரும்பாலானோர் கருத்து யாழ்ப்பாணத்தின் வரலாறு பற்றிக் கூறும் வையாபாடல் யாழ்ப்பாண வைபவமாலை போன்ற நூல்கள் யாழ்ப்பாண அரசு அரசனில்லாது இருந்தபொழுது தமிழ்நாட்டிலிருந்து அழைத்துவரப்பட்ட இளவரசனாலேயே இந்த வம்சம் ஆரம்பித்துவைக்கப் பட்டதாகக் கூறுகின்றன'

# %%
char2wd(tamil_rm(to_clean))
# Out:
# [[3, 172, 157, 52],
#  [40, 26, 14, 170, 235, 182, 104, 94, 14, 221],
#  [8, 130, 131, 96],
#  [4, 196, 39, 22, 104],
#  [95, 237, 130],
#  [235, 66],
#  [132, 14, 104, 94, 198, 174, 117, 92],
#  [158, 234, 143, 132, 79],
#  [4, 171, 52, 42, 157, 104, 100],
#  [250, 250],
#  [3, 156],
#  [110, 195, 184, 91, 70],
#  [101, 66, 26, 14, 156],
#  [250, 250, 3, 156],
#  [110, 195, 184, 91, 70],
#  [148, 195, 131, 18, 94],
#  [235, 178],
#  [3, 91, 66],
#  [2, 170, 40],
#  [235, 156, 40, 104, 96],
#  [144, 130, 118, 182, 14, 217, 26],
#  [18, 185, 26, 18, 156],
#  [4, 247, 235, 156, 40, 104, 94, 130],
#  [102, 195, 183, 156],
#  [131, 195, 185, 167],
#  [4, 235, 182, 14, 221],
#  [8, 39, 16, 174, 117, 96],
#  [235, 117, 93, 182, 14, 221],
#  [8, 130, 131, 96],
#  [131, 195, 185, 167],
#  [8, 208, 206, 174, 156],
#  [9, 195, 187, 26, 23, 221, 209, 26, 19, 68, 157],
#  [92, 14, 235, 208, 14, 221],
#  [9, 96, 156],
#  [4, 208, 204],
#  [137, 174, 156, 132, 200, 156],
#  [4, 235, 182, 14, 221],
#  [148, 92, 197, 156],
#  [145, 183, 235, 182, 144, 130],
#  [18, 196, 47, 14, 170],
#  [132, 91, 68, 157, 130],
#  [8, 130, 183],
#  [132, 91, 68, 157],
#  [144, 130, 118, 120, 130],
#  [2, 152, 52, 40, 182],
#  [3, 172, 157, 52],
#  [40, 26, 14, 170, 235, 182, 104, 94],
#  [235, 224],
#  [235, 117, 92, 235, 182, 14, 216],
#  [8, 130, 187],
#  [19, 183, 143, 131, 78, 67, 200, 156],
#  [145, 195, 187, 26],
#  [14, 174, 104, 96, 14, 213, 156],
#  [6, 221, 209, 118],
#  [4, 247, 235, 170, 48, 104],
#  [101, 66, 39, 16, 157],
#  [19, 222, 39, 22, 52],
#  [40, 26, 14, 170, 235, 182, 104, 94],
#  [98, 130, 118, 130],
#  [107, 14, 171, 118, 235, 130],
#  [8, 130, 187],
#  [141, 195, 183, 143, 131, 70, 235, 93, 208],
#  [4, 96],
#  [132, 91, 68, 157, 182],
#  [3, 87],
#  [17, 234],
#  [105, 78, 117, 92],
#  [4, 171, 52, 42, 157, 156],
#  [8, 130, 131, 96],
#  [137, 174, 156, 132, 197, 128, 182],
#  [14, 174, 104, 96],
#  [158, 234, 143, 132, 79, 104, 94, 130],
#  [235, 170, 197, 187],
#  [131, 195, 185, 26],
#  [19, 187, 156],
#  [243, 158, 132, 66, 208],
#  [158, 234, 143, 132, 79],
#  [243, 131, 235, 145, 204],
#  [141, 130, 183],
#  [110, 208, 14, 221],
#  [158, 234, 143, 132, 79],
#  [2, 170, 44],
#  [2, 170, 40, 120, 208, 197, 96],
#  [4, 174, 117, 92, 140, 226, 96],
#  [92, 146, 234, 106, 78, 68, 198, 174, 117, 96],
#  [2, 230, 104, 96, 235, 170, 143, 131, 78, 66],
#  [4, 209, 235, 170, 40, 119, 203, 164],
#  [4, 117, 92],
#  [235, 156, 40, 156],
#  [3, 170, 156, 133, 104, 96, 243, 26, 14, 143],
#  [131, 78, 66, 93, 14, 26],
#  [19, 187, 16, 130, 183, 118]]

# %%
to_clean.split()
# Out:
# ['ஆரியச்',
#  'சக்கரவர்த்திகள்',
#  'என்பது,',
#  'இலங்கைத்',
#  'தீவின்',
#  'வட',
#  'பாகத்திலிருந்த',
#  'யாழ்ப்பாண',
#  'இராச்சியத்தை',
#  '13',
#  'ஆம்',
#  'நூற்றாண்டு',
#  'தொடக்கம்',
#  '17ஆம்',
#  'நூற்றாண்டு',
#  'முற்பகுதி',
#  'வரை',
#  'ஆண்ட',
#  'அரச',
#  'வம்சத்து',
#  'மன்னர்களைக்',
#  'குறிக்கும்.',
#  'இவ்வம்சத்தின்',
#  'தோற்றம்',
#  'பற்றியோ',
#  'இவர்கள்',
#  'எங்கிருந்து',
#  'வந்தார்கள்',
#  'என்பது',
#  'பற்றியோ',
#  'எல்லோரும்',
#  'ஏற்றுக்கொள்ளக்கூடிய',
#  'தகவல்கள்',
#  'ஏதும்',
#  'இல்லை.',
#  'பெரும்பாலும்',
#  'இவர்கள்',
#  'முதலாம்',
#  'மாறவர்மன்',
#  'குலசேகர',
#  'பாண்டியன்',
#  'என்ற',
#  'பாண்டிய',
#  'மன்னனின்',
#  'அமைச்சர்',
#  'ஆரியச்',
#  'சக்கரவர்த்தி',
#  'வழி',
#  'வந்தவர்களே',
#  'என்று',
#  'கூறப்பட்டாலும்[1]',
#  'மாற்றுக்',
#  'கருத்துகளும்',
#  'உள்ளன.',
#  'இவ்வரசைத்',
#  'தொடங்கிய',
#  'கூழங்கைச்',
#  'சக்கரவர்த்தி',
#  'தென்னன்',
#  'நிகரானவன்',
#  'என்று',
#  'போற்றப்படுவதால்',
#  'இது',
#  'பாண்டியர்',
#  'ஆணை',
#  'கீழ்',
#  'நட்ந்த',
#  'இராச்சியம்',
#  'என்பது',
#  'பெரும்பாலானோர்',
#  'கருத்து.[2][3]',
#  'யாழ்ப்பாணத்தின்',
#  'வரலாறு',
#  'பற்றிக்',
#  'கூறும்',
#  'வையாபாடல்,',
#  'யாழ்ப்பாண',
#  'வைபவமாலை',
#  'போன்ற',
#  'நூல்கள்,',
#  'யாழ்ப்பாண',
#  'அரசு',
#  'அரசனில்லாது',
#  'இருந்தபொழுது,',
#  'தமிழ்நாட்டிலிருந்து',
#  'அழைத்துவரப்பட்ட',
#  'இளவரசனாலேயே',
#  'இந்த',
#  'வம்சம்',
#  'ஆரம்பித்துவைக்கப்',
#  'பட்டதாகக்',
#  'கூறுகின்றன.']

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'talink', 'abstract', 'wikidatalink', 'propertytype',
#        'property1', 'meta_name', 'meta_link', 'propertytype_list',
#        'property1_list', 'clean_abs'],
#       dtype='object')

# %%
data['clean_abs']=data['abstract'].map(tamil_rm)

# %%
clean_list=data['clean_abs'].tolist()

# %%
#joining all the abstract to get find the size of the words
joined_list="".join(clean_list)

# %%
#total no of words
len(joined_list.split())
# Out:
# 626846

# %%
allwords=joined_list.split()

# %%
allwords
# Out:
# ['ஒரு',
#  'கட்டிடக்கலைஞன்',
#  'அல்லது',
#  'கட்டிடச்சிற்பி',
#  'என்பவன்',
#  'கட்டிடத்',
#  'திட்டமிடல்',
#  'வடிவமைப்பு',
#  'மற்றும்',
#  'கட்டிட',
#  'நிர்மாண',
#  'மேற்பார்வை',
#  'என்பவற்றில்',
#  'தேர்ச்சி',
#  'பெற்ற',
#  'ஒருவனாவான்',
#  'கட்டிடக்கலையைப்',
#  'பார்க்கவும்',
#  'கட்டிடக்கலைஞர்கள்',
#  'மருத்துவர்கள்',
#  'வக்கீல்கள்',
#  'மற்றும்',
#  'பொறியியலாளர்களைப்போல',
#  'உயர்தொழில்',
#  'வல்லுனர்களாகக்',
#  'கணிக்கப்படுகிறார்கள்',
#  'ஒரு',
#  'கட்டிடக்கலைஞன்',
#  'பெறக்கூடிய',
#  'அதி',
#  'கௌரவம்',
#  'பிரிட்ஸ்கெர்',
#  'பரிசு',
#  'ஆகும்குறிப்பிடத்தக்க',
#  'கட்டிடக்கலைஞர்களின்',
#  'பட்டியல்எமிரேட்ஸ்',
#  'கோபுரங்கள்',
#  'என',
#  'அழைக்கப்படும்',
#  'இரட்டைக்',
#  'கோபுரங்கள்',
#  'டுபாயிலுள்ள',
#  'ஷேக்',
#  'ஸயத்',
#  'வீதி',
#  'என்று',
#  'பெயரிடப்பட்டுள்ள',
#  'துபாய்',
#  '-',
#  'அபுதாபி',
#  'பெருந்தெருவை',
#  'அண்டி',
#  'அமைந்துள்ளது',
#  'முக்கோணவடிவ',
#  'வெட்டுமுகத்தையுடைய',
#  'இவ்விரு',
#  'கோபுரங்களிலொன்று',
#  'மற்றதிலும்',
#  'சிறிது',
#  'உயரமானது',
#  'இக்',
#  'கட்டிடத்தின்',
#  'கீழ்த்',
#  'தளங்கள்',
#  'பரந்த',
#  'ஒரு',
#  'ஆக',
#  'அமைந்து',
#  'மேற்படி',
#  'இரு',
#  'கோபுரங்களையும்',
#  'தாங்குவது',
#  'போலுள்ளது',
#  ':ஐக்கிய',
#  'அரபு',
#  'அமீரகத்திலுள்ள',
#  'ஒவ்வொரு',
#  'அமீரகத்திலும்',
#  'ஒன்றிரண்டு',
#  'நகரங்களே',
#  'உள்ளன',
#  'அமீரகங்களும்',
#  'அவற்றின்',
#  'தலைநகரங்களும்',
#  'ஒரே',
#  'பெயராலேயே',
#  'அழைக்கப்படுகின்றன',
#  'இந்',
#  'நகரங்கள்',
#  'மாநகரசபைகளால்',
#  'நிர்வகிக்கப்படுகின்றன',
#  'இவற்றுள்',
#  'அபுதாபி',
#  'முழுநாட்டினதும்',
#  'தலைநகரமாக',
#  'உள்ளது',
#  'துபாய்',
#  'நகரம்',
#  'வர்த்தக',
#  'ரீதியில்',
#  'முதன்மை',
#  'பெற்ற',
#  'நகரமாக',
#  'விளங்குகிறது',
#  'கீழேயுள்ள',
#  'பட்டியலில்',
#  'அல்',
#  'எயின்',
#  'தவிர்ந்த',
#  'எல்லா',
#  'நகரங்களும்',
#  'கடற்கரை',
#  'நகரங்களாகும்',
#  'அல்',
#  'எயின்',
#  'நகரம்',
#  'அபுதாபி',
#  'அமீரகத்தின்',
#  'ஒரு',
#  'பகுதியாகும்',
#  'கீழே',
#  'தரப்பட்டுள்ள',
#  'எல்லா',
#  'நகரங்களும்',
#  'ஒரே',
#  'தரத்தில்',
#  'வைக்கப்பட்டிருந்தாலும்',
#  'முதல்',
#  'நான்கும்',
#  'தவிர்ந்த',
#  'ஏனையவை',
#  'ஒப்பீட்டளவில்',
#  'மிகவும்',
#  'சிறியவை',
#  'ஆகும்கிமு',
#  '6ம்',
#  'நூற்றாண்டு',
#  'என்பது',
#  'கிமு',
#  '600',
#  'ஆம்',
#  'ஆண்டின்',
#  'முதல்',
#  'நாளில்',
#  'இருந்து',
#  'கிமு',
#  '501',
#  'ஆம்',
#  'ஆண்டின்',
#  'கடைசி',
#  'நாளன்று',
#  'முடிவடைந்த',
#  'காலப்பகுதியைக்',
#  'குறிக்கும்விண்வெளி',
#  'என்பது',
#  'ஒப்பீட்டளவில்',
#  'கோள்களின்',
#  'காற்று',
#  'மண்டலத்துக்கு',
#  'வெளியேயுள்ள',
#  'பிரபஞ்சத்தின்',
#  'வெறுமையான',
#  'பகுதியாகும்',
#  'இது',
#  'பூமியின்',
#  'மேற்பரப்பிலிருந்து',
#  'கிட்டத்தட்ட',
#  '100',
#  'கிமீற்றருக்கு',
#  'மேலே',
#  'ஆரம்பமாவதாகக்',
#  'கொள்ளலாம்',
#  'விண்வெளி',
#  'அறிவியல்',
#  'அல்லது',
#  'விண்வெளி',
#  'அறிவியல்கள்',
#  'பின்வருவன',
#  'போன்ற',
#  'பல்வேறு',
#  'துறைகளை',
#  'அடக்கியுள்ளதுபிரபலமான',
#  'அல்லது',
#  'குறிப்பிடத்தக்க',
#  'கட்டிடங்கள்:கட்டிடக்கலை',
#  'என்பது',
#  'கட்டிடங்கள்',
#  'மற்றும்',
#  'அதன்',
#  'உடல்',
#  'கட்டமைப்புகளை',
#  'வடிவமைத்தல்',
#  'செயல்முறைத்',
#  'திட்டமிடல்',
#  'மற்றும்',
#  'கட்டிடங்கள்',
#  'கட்டுவதை',
#  'உள்ளடக்கியதாகும்',
#  'கட்டடக்கலை',
#  'படைப்புகள்',
#  'கட்டிடங்கள்',
#  'பொருள்',
#  'வடிவம்',
#  'பெரும்பாலும்',
#  'கலாச்சார',
#  'சின்னங்களாக',
#  'மற்றும்',
#  'கலை',
#  'படைப்புகளாக',
#  'காணப்படுகின்றது',
#  'வரலாற்று',
#  'நாகரிகங்கள்',
#  'பெரும்பாலும்',
#  'அவர்களின்',
#  'கட்டிடகலை',
#  'சாதனைகளின்',
#  'மூலம்',
#  'அடையாளம்',
#  'காணப்படுகின்றனவிண்வெளி',
#  'நிலையம்',
#  'என்பது',
#  'விண்ணில்',
#  'மனிதர்',
#  'வாழ்வதற்கென',
#  'வடிவமைக்கப்பட்டு',
#  'மனிதனால்',
#  'செய்யப்பட்ட',
#  'ஒரு',
#  'அமைப்பாகும்',
#  'விண்வெளி',
#  'நிலையம்',
#  'பெரிய',
#  'அளவில்',
#  'உந்தல்',
#  'அல்லது',
#  'இறங்கல்',
#  'வசதிகளைக்',
#  'கொண்டிராமையை',
#  'வைத்து',
#  'ஏனைய',
#  'ஆளேற்றிய',
#  'விண்கலங்களிலிருந்து',
#  'வேறுபடுத்தப்படுகிறது',
#  '-',
#  'பதிலாக',
#  'விண்வெளி',
#  'நிலையத்திலிருந்து',
#  'போக்குவரத்துக்கு',
#  'ஏனைய',
#  'வாகனங்கள்',
#  'பயன்படுகின்றன',
#  'விண்வெளி',
#  'நிலையங்கள்',
#  'சுற்றுப்பாதையில்',
#  'சில',
#  'மாதங்களைக்கொண்ட',
#  'இடைத்தரக்',
#  'கால',
#  'அளவு',
#  'வாழ்க்கைக்காக',
#  'வடிவமைப்புச்',
#  'செய்யப்படுகின்றனஇந்தப்',
#  'பக்கம்',
#  'இனவாரியாக',
#  'பிரஜா',
#  'உரிமைவாரியாக',
#  'மொழிவாரியாக',
#  'அமைவிடவாரியாக',
#  'ஆட்களின்',
#  'பட்டியல்கள்',
#  'போன்ற',
#  'தொடர்பான',
#  'பட்டியல்களையும்',
#  'உள்ளடக்குகிறதுபென்னி',
#  'பிளாக்',
#  'உலகின்',
#  'முதலாவது',
#  'உத்தியோகபூர்வ',
#  'ஒட்டக்கூடிய',
#  'தபால்தலையாகும்',
#  'இது',
#  'பெரிய',
#  'பிரித்தானியாவால்',
#  '1840',
#  'மே',
#  '1',
#  'அன்று',
#  'மே',
#  '6ம்',
#  'திகதியிலிருந்து',
#  'உபயோகிப்பதற்காக',
#  'வெளியிடப்பட்டதுகட்டிடக்கலைஞனின்',
#  'கற்பனையில்',
#  'உதித்த',
#  'கட்டிடமொன்று',
#  'எப்படி',
#  'இருக்கப்போகிறது',
#  'என்று',
#  'மற்றவர்கள்',
#  'விளங்கிக்',
#  'கொள்வதற்காக',
#  'வரையப்படும்',
#  'படங்களே',
#  'கட்டிட',
#  'வரைபடங்கள்',
#  'என்று',
#  'அழைக்கப்படுகின்றன',
#  'கட்டிடங்கள்',
#  'வடிவமைப்புச்',
#  'செய்யத்',
#  'தொடங்கியதிலிருந்து',
#  'அது',
#  'கட்டிமுடியும்வரை',
#  'பல்வேறு',
#  'நோக்கங்களூக்காக',
#  'வரைபடங்கள்',
#  'வரையப்படுகின்றன',
#  'பின்வரும்',
#  'சந்தர்ப்பங்களில்',
#  'வரைபடங்கள்',
#  'தேவைப்படுகின்றனஅஞ்சல்தலை',
#  'சேகரிப்பு',
#  'என்பது',
#  'அஞ்சல்தலைகளையும்',
#  'அதனுடன்',
#  'தொடர்புடைய',
#  'வேறு',
#  'பொருட்களையும்',
#  'சேகரித்தல்',
#  'என்று',
#  'பொருள்படும்',
#  'இது',
#  'உலகின்',
#  'மிகப்',
#  'பரலமான',
#  'பொழுது',
#  'போக்குகளில்',
#  'ஒன்று',
#  'உலக',
#  'அளவில்',
#  'பரவி',
#  'இருந்தும்',
#  'பெரும்பாலானோருக்கு',
#  'இது',
#  'ஒரு',
#  'இலாபமில்லாத',
#  'முயற்சியாகவே',
#  'இருந்து',
#  'வருகிறது',
#  'எனினும்',
#  'சில',
#  'சிறிய',
#  'நாடுகள்',
#  'நுணுக்கமாக',
#  'வடிவமைக்கப்பட்ட',
#  'சிறுதொகையான',
#  'அஞ்சல்தலைகளை',
#  'அஞ்சல்தலை',
#  'சேகரிப்பாளர்களைக்',
#  'கருத்தில்',
#  'கொண்டு',
#  'மட்டுமே',
#  'வெளியிட்டு',
#  'வருமானம்',
#  'பெறுகின்றன',
#  'இந்நாடுகள்',
#  'வெளியிடும்',
#  'அஞ்சல்',
#  'தலைகள்',
#  'அவற்றின்',
#  'அஞ்சல்',
#  'துறைத்',
#  'தேவைகளிலும்',
#  'அதிகமாகவே',
#  'இருக்கும்தேசியக்',
#  'கொடி',
#  'என்பது',
#  'நாடொன்றிற்குக்',
#  'குறியீடாக',
#  'அமையும்',
#  'ஒரு',
#  'கொடியாகும்',
#  'இது',
#  'அந்நாட்டுக்',
#  'குடிமக்களால்',
#  'பறக்கவிடப்படக்கூடியது',
#  'வழக்கமாக',
#  'இதே',
#  'கொடியே',
#  'அந்த',
#  'நாடுகளை',
#  'வெளிநாடுகளில்',
#  'பிரதிநிதித்துவப்படுத்தவும்',
#  'பயன்படுகிறதுஅஞ்சற்றலை',
#  'அல்லது',
#  'தபால்தலை',
#  'என்பது',
#  'அஞ்சல்',
#  'சேவைக்கு',
#  'முன்',
#  'கட்டணம்',
#  'செலுத்தப்பட்டதற்குச்',
#  'சான்றாக',
#  'கொடுக்கப்படுவது',
#  'பொதுவாக',
#  'இது',
#  'ஒரு',
#  'நீள்சதுர',
#  'வடிவிலமைந்த',
#  'சிறு',
#  'காகிதத்',
#  'துண்டாக',
#  'இருக்கும்',
#  'தபால்',
#  'சேவை',
#  'மூலம்',
#  'அனுப்பப்படவுள்ள',
#  'கடிதஉறையில்',
#  'மேற்சொன்ன',
#  'தபால்தலைகளை',
#  'ஒட்டுவதன்',
#  'மூலம்',
#  'அக்',
#  'கடிதத்தை',
#  'அனுப்புபவர்',
#  'அதை',
#  'அனுப்புவதற்கான',
#  'கட்டணத்தைச்',
#  'செலுத்தியுள்ளார்',
#  'என்பதற்குச்',
#  'சான்று',
#  'அளிக்கின்றார்',
#  'முன்',
#  'கட்டணம்',
#  'செலுத்தப்பட்ட',
#  'உறைகளைப்',
#  'பயன்படுத்துவதிலும்',
#  'பார்க்க',
#  'அதிகம்',
#  'விரும்பப்படும்',
#  'முறை',
#  'இதுவாகும்இக்கோல்',
#  'டெஸ்',
#  'பியூக்ஸ்',
#  'ஆர்ட்ஸ்',
#  'என்பது',
#  'பிரெஞ்சு',
#  'மொழியில்',
#  'கவின்கலைக்',
#  'கல்லூரி',
#  'என்னும்',
#  'பொருள்',
#  'தருவது',
#  'இப்',
#  'பெயரில்',
#  'பிரான்ஸில்',
#  'பல',
#  'கலைக்',
#  'கல்லுரிகள்',
#  'உள்ளன',
#  'பழையதும்',
#  'பிரபலமானதுமான',
#  'நிறுவனம்',
#  'பாரிஸில்',
#  'அமைந்துள்ளதுஅறிவியல்',
#  'மற்றும்',
#  'தொழில்நுட்பவியலின்',
#  'வரலாறு',
#  'என்பதுஅறிவியலும்',
#  'தொழில்நுட்பமும்',
#  'பற்றிய',
#  'மனித',
#  'இனத்தின்',
#  'விளக்கம்',
#  'காலங்களூடாக',
#  'எவ்வாறு',
#  'மாற்றமடைந்து',
#  'வருகின்றது',
#  'என்றும்',
#  'இவ்விளக்கம்',
#  'எவ்வாறு',
#  'புதிய',
#  'தொழில்நுட்பங்களை',
#  'உருவாக்குவதில்',
#  'உதவியது',
#  'என்பதுபற்றியும்',
#  'ஆராயும்',
#  'ஒரு',
#  'வரலாற்றுத்',
#  'துறையாகும்',
#  'பண்பாட்டு',
#  'பொருளியல்',
#  'மற்றும்',
#  'அரசியல்',
#  'துறைகளில்',
#  'அறிவியற்',
#  'புத்தாக்கங்களின்',
#  'தாக்கங்கள்',
#  'பற்றியும்',
#  'இத்',
#  'துறை',
#  'ஆராய்கிறதுயாழ்ப்பாணக்',
#  'குடாநாடு',
#  'இலங்கைத்தீவின்',
#  'வடக்கு',
#  'அந்தலையில்',
#  'அமைந்துள்ளது',
#  'இதன்',
#  'வடக்கிலும்',
#  'கிழக்கிலும்',
#  'இந்தியப்',
#  'பெருங்கடலும்',
#  'மற்றும்',
#  'மேற்கிலும்',
#  'தெற்கிலும்',
#  'யாழ்ப்பாணக்',
#  'கடலேரியும்',
#  'அமைந்துள்ளது',
#  'இந்தக்',
#  'குடாநாடு',
#  'ஆனையிறவு',
#  'என்ற',
#  'இடத்தில்',
#  'ஒரு',
#  'ஒடுங்கிய',
#  'நிலப்பகுதி',
#  'மூலம்',
#  'தெற்கேயுள்ள',
#  'தாய்',
#  'நிலமான',
#  'வன்னிப்',
#  'பகுதியுடன்',
#  'இணைக்கப்பட்டுள்ளது',
#  'இதேபோல்',
#  'கிழக்குக்',
#  'கரையோரத்திலும்',
#  'ஓர்',
#  'ஒடுக்கமான',
#  'நில',
#  'இணைப்பு',
#  'உண்டுஇந்தியத்',
#  'துணைக்கண்டம்',
#  'என்பது',
#  'இந்தியா',
#  'வங்காளதேசம்',
#  'பாகிஸ்தான்',
#  'ஆப்கானித்தான்',
#  'நேபாளம்',
#  'பூட்டான்',
#  'இலங்கை',
#  'மாலத்தீவு',
#  'மியன்மார்',
#  'மற்றும்',
#  'சீனாவின்',
#  'திபெத்',
#  'தன்னாட்சிப்',
#  'பகுதிகளை',
#  'உள்ளடக்கிய',
#  'தெற்காசியாவின்',
#  'ஒரு',
#  'புவியியல்',
#  'பகுதியாகும்',
#  'ஆரியச்',
#  'சக்கரவர்த்திகள்',
#  'என்பது',
#  'இலங்கைத்',
#  'தீவின்',
#  'வட',
#  'பாகத்திலிருந்த',
#  'யாழ்ப்பாண',
#  'இராச்சியத்தை',
#  '13',
#  'ஆம்',
#  'நூற்றாண்டு',
#  'தொடக்கம்',
#  '17ஆம்',
#  'நூற்றாண்டு',
#  'முற்பகுதி',
#  'வரை',
#  'ஆண்ட',
#  'அரச',
#  'வம்சத்து',
#  'மன்னர்களைக்',
#  'குறிக்கும்',
#  'இவ்வம்சத்தின்',
#  'தோற்றம்',
#  'பற்றியோ',
#  'இவர்கள்',
#  'எங்கிருந்து',
#  'வந்தார்கள்',
#  'என்பது',
#  'பற்றியோ',
#  'எல்லோரும்',
#  'ஏற்றுக்கொள்ளக்கூடிய',
#  'தகவல்கள்',
#  'ஏதும்',
#  'இல்லை',
#  'பெரும்பாலும்',
#  'இவர்கள்',
#  'முதலாம்',
#  'மாறவர்மன்',
#  'குலசேகர',
#  'பாண்டியன்',
#  'என்ற',
#  'பாண்டிய',
#  'மன்னனின்',
#  'அமைச்சர்',
#  'ஆரியச்',
#  'சக்கரவர்த்தி',
#  'வழி',
#  'வந்தவர்களே',
#  'என்று',
#  'கூறப்பட்டாலும்',
#  'மாற்றுக்',
#  'கருத்துகளும்',
#  'உள்ளன',
#  'இவ்வரசைத்',
#  'தொடங்கிய',
#  'கூழங்கைச்',
#  'சக்கரவர்த்தி',
#  'தென்னன்',
#  'நிகரானவன்',
#  'என்று',
#  'போற்றப்படுவதால்',
#  'இது',
#  'பாண்டியர்',
#  'ஆணை',
#  'கீழ்',
#  'நட்ந்த',
#  'இராச்சியம்',
#  'என்பது',
#  'பெரும்பாலானோர்',
#  'கருத்து',
#  'யாழ்ப்பாணத்தின்',
#  'வரலாறு',
#  'பற்றிக்',
#  'கூறும்',
#  'வையாபாடல்',
#  'யாழ்ப்பாண',
#  'வைபவமாலை',
#  'போன்ற',
#  'நூல்கள்',
#  'யாழ்ப்பாண',
#  'அரசு',
#  'அரசனில்லாது',
#  'இருந்தபொழுது',
#  'தமிழ்நாட்டிலிருந்து',
#  'அழைத்துவரப்பட்ட',
#  'இளவரசனாலேயே',
#  'இந்த',
#  'வம்சம்',
#  'ஆரம்பித்துவைக்கப்',
#  'பட்டதாகக்',
#  'கூறுகின்றனயாழ்ப்பாண',
#  'வரலாற்று',
#  'ஆய்வாளர்கள்',
#  'அனைவரும்',
#  'அதனையாண்ட',
#  'அரசர்கள்',
#  'பட்டியலுக்கு',
#  'யாழ்ப்பாண',
#  'வைபவமாலையையே',
#  'முக்கிய',
#  'ஆதாரமாகக்',
#  'கொண்டுள்ளனர்',
#  'எனினும்',
#  'யாழ்ப்பாண',
#  'வைபவமாலை',
#  'தரும்',
#  'அவர்களது',
#  'காலம்',
#  'பற்றிய',
#  'தகவல்கள்',
#  'கிடைக்கக்',
#  'கூடிய',
#  'ஏனைய',
#  'தகவல்களுடன்',
#  'பொருந்தி',
#  'வராமையினால்',
#  'வெவ்வேறு',
#  'ஆய்வாளர்களுடைய',
#  'முடிவுகளுக்கிடையே',
#  'வேறுபாடுகள்',
#  'காணப்படுகின்றன',
#  'கீழேயுள்ள',
#  'பட்டியல்',
#  'நல்லூர்',
#  'சுவாமி',
#  'ஞானப்பிரகாசர்',
#  'எழுதி',
#  '1928ல்',
#  'வெளியிடப்பட்ட',
#  'யாழ்ப்பாண',
#  'வைபவ',
#  'விமர்சனம்',
#  'மற்றும்',
#  '1926ல்',
#  'வெளிவந்த',
#  'முதலியார்',
#  'செ',
#  'இராசநாயகம்',
#  'அவர்களுடைய',
#  'பழங்கால',
#  'யாழ்ப்பாணம்',
#  'என்ற',
#  'ஆங்கில',
#  'நூல்',
#  'ஆகியவற்றில்',
#  'காணப்படும்',
#  'காலக்கணிப்பைத்',
#  'தருகிறதுயாழ்ப்பாணத்து',
#  'வரலாற்று',
#  'நூலான',
#  'யாழ்ப்பாண',
#  'வைபவமாலையின்படி',
#  'யாழ்ப்பாண',
#  'இராச்சியத்தை',
#  'ஆண்ட',
#  'ஆரியச்',
#  'சக்கரவர்த்திகள்',
#  'வம்சத்தின்',
#  'முதலாவது',
#  'மன்னன்',
#  'கூழங்கைச்',
#  'சக்கரவர்த்தியாவான்',
#  'இவன்',
#  'தென்னன்',
#  'நிகரானவன்',
#  'என்று',
#  'போற்றப்படுவதால்',
#  'பாண்டியர்',
#  'கீழ்',
#  'ஆட்சி',
#  'புரிந்த',
#  'பாண்டிய',
#  'அமைச்சன்',
#  'என்று',
#  'கூறுவோரும்',
#  'உண்டு',
#  'வையாபாடல்',
#  'இப்',
#  'பெயரின்',
#  'வடமொழியாக்கமான',
#  'கோளுறு',
#  'கரத்துக்',
#  'குரிசில்',
#  'என்ற',
#  'பெயரில்',
#  'இவனைக்',
#  'குறிப்பிடும்',
#  'இவன்',
#  'கை',
#  'ஊனமுற்று',
#  'இருந்த',
#  'காரணத்தால்',
#  '"கூழங்கையன்"',
#  'என',
#  'அழைக்கப்பட்டுப்',
#  'பின்னர்',
#  '"கூழங்கைச்',
#  'சக்கரவர்த்தி"',
#  'அல்லது',
#  '"கூழங்கை',
#  'ஆரியச்சக்கரவர்த்தி"',
#  'எனப்',
#  'பெயர்',
#  'பெற்றதாகக்',
#  'கூறப்படுகிறதுபொதுவாக',
#  'விட்ருவியஸ்',
#  'என்று',
#  'அழைக்கப்படும்',
#  'மார்க்கஸ்',
#  'விட்ருவியஸ்',
#  'பொல்லியோ',
#  'ஒரு',
#  'ரோமானிய',
#  'எழுத்தாளரும்',
#  'கட்டிடக்கலைஞரும்',
#  'பொறியியலாளருமாவார்',
#  'இவர்',
#  'கிமு',
#  'முதலாவது',
#  'நூற்றாண்டளவில்',
#  'வாழ்ந்தவர்',
#  'ஆரம்பத்தில்',
#  'ரோமானியச்',
#  'சக்கரவர்த்தியான',
#  'ஜூலியஸ்',
#  'சீசருக்குக்',
#  'கீழும்',
#  'பின்னர்',
#  'முதலாம்',
#  'அகஸ்டசுக்குக்',
#  'கீழும்',
#  'பொறியியலாளராகப்',
#  'பணியாற்றினார்',
#  'பணியிலிருந்து',
#  'இளைப்பாறிய',
#  'பின்',
#  '10',
#  'தொகுதிகளைக்',
#  'கொண்ட',
#  'கட்டிடக்கலை',
#  'பற்றிய',
#  'தனது',
#  'நூலை',
#  'எழுதினார்',
#  'இதுவே',
#  'இன்று',
#  'கிடைக்கக்',
#  'கூடிய',
#  'காலத்தால்',
#  'முற்பட்ட',
#  'கட்டிடக்கலை',
#  'நூலாகக்',
#  'கருதப்படுகிறதுஇந்தப்',
#  'பக்கங்கள்',
#  'ஆயிரவாண்டுகளினதும்',
#  'நூற்றாண்டுகளினதும்',
#  'போக்குகளைக்',
#  'கொண்டுள்ளன',
#  'தனித்தனி',
#  'நூற்றாண்டுப்',
#  'பக்கங்கள்',
#  'தசாப்தங்களையும்',
#  'ஆண்டுகளையும்',
#  'பட்டியலிட்டுள்ளன',
#  'வரலாற்று',
#  'நிகழ்வுகளின்',
#  'வெவ்வேறு',
#  'ஒழுங்கமைப்புகளுக்கு',
#  'வரலாறு',
#  'பக்கத்தைப்',
#  'பார்க்கவும்கொழுப்பு',
#  'அமிலம்',
#  'என்பது',
#  'நிறைவுற்ற',
#  'அல்லது',
#  'நிறைவுறாத',
#  'நீளமான',
#  'கிளைக்காத',
#  'கொழுப்பார்ந்த',
#  'பின்',
#  'தொடரியைக்',
#  'கொண்ட',
#  'கார்பாக்சிலிக்',
#  'அமிலமாகும்',
#  'இயற்கையில்',
#  'காணப்படும்',
#  'கொழுப்பு',
#  'அமிலங்கள்',
#  'இரட்டைப்',
#  'படை',
#  'எண்ணிக்கையில்',
#  'கார்பன்',
#  'அணுக்களை',
#  'தொடரியாகக்',
#  'கொண்டிருக்கும்',
#  'சாதரணமாக',
#  'கொழுப்பு',
#  'அமிலங்கள்',
#  'டிரைகிளிசரைடு',
#  'மற்றும்',
#  'பாஸ்போகொழுமியத்திலிருந்து',
#  'வருவிக்கப்பட்டவையாகும்',
#  'கொழுப்பு',
#  'அமிலங்கள்',
#  'பிற',
#  'மூலக்கூறுகளுடன்',
#  'இணைக்கப்படாமல்',
#  'இருக்கும்போது',
#  'தனிக்கொழுப்பு',
#  'அமிலங்கள்',
#  'என்றழைக்கப்படுகின்றன',
#  'மேலும்வாஸ்து',
#  'சாஸ்திரம்',
#  'என்பது',
#  'நகர',
#  'அமைப்பு',
#  'கட்டிடக்கலை',
#  'என்பன',
#  'சம்பந்தப்பட்ட',
#  'இந்தியாவின்',
#  'மிகவும்',
#  'பழமையான',
#  'அறிவுத்துறைகளில்',
#  'ஒன்றாகும்',
#  '"வாஸ்து"',
#  'என்றசொல்',
#  'கட்டிடமொன்று',
#  'கட்டப்பட்டுள்ள',
#  'அல்லது',
#  'கட்டப்படவுள்ள',
#  'நிலத்தைக்',
#  'குறிக்கும்',
#  '"வாஸ்து',
#  'சாஸ்திரம்"',
#  'என்பது',
#  'ஒரு',
#  'நிலத்தில்',
#  'கட்டிடம்',
#  'கட்டுவதற்குரிய',
#  'முறைகளையும்',
#  'அதன்',
#  'தத்துவங்களையும்',
#  'விளக்கும்',
#  'ஒரு',
#  'வேதம்',
#  'சார்ந்த',
#  'அறிவுத்துறையாகும்சியேர்ஸ்',
#  'கோபுரம்',
#  'சிகாகோ',
#  'இலினாயிசிலுள்ள',
#  'ஒரு',
#  'வானளாவி',
#  'ஆகும்',
#  'கட்டுமானப்பணிகள்',
#  '1970',
#  'ஆகஸ்ட்',
#  'மாதத்தில்',
#  'தொடங்கி',
#  '1973',
#  'மே',
#  '4ல்',
#  'இதன்',
#  'அதியுயர்',
#  'உயரத்தை',
#  'அடைந்தது',
#  'இது',
#  'கட்டி',
#  'முடிக்கப்பட்டபோது',
#  'நியூயார்க்கிலிருந்த',
#  'உலக',
#  'வர்த்தக',
#  'மைய',
#  'இரட்டைக்',
#  'கோபுரங்களை',
#  'உயரத்தில்',
#  'விஞ்சி',
#  'உலகின்',
#  'அதியுயர்ந்த',
#  'கட்டிடம்',
#  'என்ற',
#  'இடத்தைப்',
#  'பிடித்தது',
#  'இது',
#  '110',
#  'மாடிகளைக்கொண்ட',
#  '443',
#  'மீட்டர்',
#  'உயரமுள்ளதாகும்',
#  'இக்கட்டிடத்தின்',
#  'உச்சியிலுள்ள',
#  'இரண்டு',
#  'தொலைக்',
#  'காட்சி',
#  'அண்டனாக்கள்',
#  'உட்பட',
#  'இந்த',
#  'அமைப்பின்',
#  'மொத்த',
#  'உயரம்',
#  '520',
#  'மீட்டர்',
#  'ஆகும்',
#  'உச்சியிலுள்ள',
#  'அலங்கார',
#  'ஈட்டியமைப்பு',
#  'உட்பட',
#  '542',
#  'மீட்டர்',
#  'உயரமான',
#  'மலேஷியா',
#  'கோலாலம்பூரிலுள்ள',
#  'பெட்ரோனாஸ்',
#  'கோபுரங்கள்',
#  '1997ல்',
#  'உலகின்',
#  'அதியுயர்ந்த',
#  'கட்டிடம்',
#  'என்ற',
#  'பெருமையை',
#  'சியேர்ஸ்',
#  'கோபுரத்திடமிருந்து',
#  'தட்டிக்கொண்டது',
#  'சியேர்ஸ்',
#  'கோபுரம்',
#  'ஐக்கிய',
#  'அமெரிக்காவின்',
#  'அதியுயர்ந்த',
#  'அலுவலகக்',
#  'கட்டிடம்',
#  'என்ற',
#  'பெருமையையும்',
#  'அதன்',
#  'பிரதான',
#  'வாயிலுக்கருகிலுள்ள',
#  'நடைபாதையிலிருந்து',
#  'அண்டெனா',
#  'உச்சிவரையுள்ள',
#  ...]

# %%
#uniq_no of words
uniq_word=list((set((joined_list.split()))))

# %%
len(uniq_word)
# Out:
# 135782

# %%
count_list=list(map(len,allwords))

# %%
#word_len count
[[x,count_list.count(x)] for x in set(count_list)]
# Out:
# [[1, 3562],
#  [2, 14191],
#  [3, 43018],
#  [4, 54531],
#  [5, 58260],
#  [6, 70106],
#  [7, 72226],
#  [8, 61592],
#  [9, 52741],
#  [10, 43739],
#  [11, 38350],
#  [12, 28047],
#  [13, 22440],
#  [14, 17393],
#  [15, 11674],
#  [16, 8203],
#  [17, 8407],
#  [18, 4209],
#  [19, 3249],
#  [20, 2675],
#  [21, 1870],
#  [22, 1625],
#  [23, 1128],
#  [24, 1082],
#  [25, 658],
#  [26, 495],
#  [27, 386],
#  [28, 264],
#  [29, 202],
#  [30, 160],
#  [31, 100],
#  [32, 81],
#  [33, 48],
#  [34, 37],
#  [35, 19],
#  [36, 17],
#  [37, 19],
#  [38, 12],
#  [39, 9],
#  [40, 1],
#  [42, 3],
#  [43, 4],
#  [44, 1],
#  [45, 4],
#  [46, 3],
#  [47, 1],
#  [48, 1],
#  [49, 1],
#  [52, 1],
#  [58, 1]]

# %%
sorted_uniq_words = sorted(uniq_word, key=lambda x :len(x),reverse=True)

# %%
len(sorted_uniq_words[:200][0])
# Out:
# 58

# %%
sorted_uniq_words[:200]
# Out:
# ['பார்க்கவும்செயலாட்சியர்செயலாட்சியர்செயலாட்சியர்கட்டுரையில்',
#  'புகுத்தியுள்ளார்பொருநன்சிறுபாணான்பெரும்பாணான்கூத்தர்',
#  'சிவாலயமாகும்வார்ப்புருஒலிம்பிக்ப்பதக்கம்அப்பாச்சி',
#  'சொற்பொழிவுகளும்செயல்விளக்கங்களும்பயிலரங்கங்களும்',
#  'புதுக்கோட்டைலிருந்துபேராவூரணிபட்டுக்கோட்டைக்கான',
#  'பல்கலைக்கழகங்களிலும்கல்லூரிகளிலும்பள்ளிகளிலும்',
#  'பொறியியல்தொழில்நுட்பம்கட்டிடக்கலைமருந்துகளியல்',
#  'நம்பப்படுகிறதுஅருங்காட்சியகங்களில்அமேசான்காம்',
#  'கலைகல்விதொழில்இலக்கியம்அறிவியல்விளையாட்டுசமூக',
#  'பொறியியல்தொழில்நுட்பம்கட்டிடக்கலைமருந்துவியல்',
#  'சென்னைகாஞ்சிபுரம்கடலூர்சேலம்தர்மபுரிதஞ்சாவூர்',
#  'தேர்ந்தெடுக்கப்பட்டார்தொண்டரடிப்பொடியாழ்வார்',
#  'சிவசிதம்பரம்அமிர்தலிங்கம்சம்பந்தன்விடுதலைப்',
#  'ஏற்றுக்கொள்ளப்படக்கூடியதாகும்வர்ணகுலசிங்கம்',
#  'வெளியீடுசென்னை98முதல்பதிப்புூலை2008திணைமாலை',
#  'பயன்படுத்தப்பட்டதுசெயலாட்சியர்இரட்டைப்படைக்',
#  'தேர்ந்தெடுக்கப்பட்டிருக்கின்றார்மேற்கத்திய',
#  'மார்க்சிட்டுகள்அராகவாதிகள்சமூகனநாயகவாதிகள்',
#  'பகுதியில்நகர்ப்புறங்களில்கிராமப்புறங்களில்',
#  'சேர்க்கப்பட்டிருக்கின்றனர்வாசுதேவநல்லூர்',
#  'அறியலாம்செயலாட்சியர்செயலாட்சியர்இரத்தக்',
#  'தெரிவித்தார்மாதிரிகாட்சிகட்டுப்பாட்டகம்',
#  'அடையாளப்படுத்தப்படுவதுண்டுஉணர்வுப்பதிவு',
#  'கலைஅறிவியல்பண்பாடுகல்விஇலக்கியம்இதழியல்',
#  'பயன்படுத்தப்படுகின்றனகட்டுமானத்துறையில்',
#  'இனத்தால்பண்பாட்டால்பொருளியலால்அரசியலால்',
#  'இயக்கமாகும்செயலாட்சியர்செயலாட்சியர்அசல்',
#  'அங்கீகரிக்கப்பட்டுள்ளதுஅமெரிக்காக்களின்',
#  'பிரதிநிதித்துவப்படுத்தியுள்ளார்கொழுப்பு',
#  'கூறியிருக்கிறார்கள்ார்ட்்ஃபீல்ட்ாக்சன்',
#  'சித்தரிக்கப்படுகிறதுஉணர்வுப்பதிவுவாதம்',
#  'பிரித்தெடுக்கப்படுகின்றதுகுரோவாட்்க்கா',
#  'ஒழுங்குபடுத்துகின்றகட்டுப்படுத்துகின்ற',
#  'மாதவன்பாவனாநடித்துள்ளார்கள்இத்திரைபடம்',
#  'குறிப்பிடப்பட்டுள்ளதுதிருப்பயத்தங்குடி',
#  'தொகுக்கப்பட்டுள்ளதுவினைபடுபொருளுக்கும்',
#  'குறிப்பிடத்தக்கதுதிருக்கானப்பேருடையான்',
#  'கேட்டுக்கொள்ளப்படுகிறார்கள்புடைசூழ்ந்த',
#  'வரலாறுகுறிப்பிடப்பட்டுள்ளதுபிரயோபைட்டா',
#  'விரும்பப்படுகின்றதுஒப்பந்தச்சட்டத்தில்',
#  'அராகவாதிகளுக்கும்மார்க்சிட்டுகளுக்கும்',
#  'பட்டியலிடப்பட்டுள்ளனதகரமினுக்கமூட்டிய',
#  'அறிமுகப்படுத்தப்பட்டதுபிள்ளையார்பட்டி',
#  'திரைப்படங்களாக்கப்பட்டுள்ளனமுடியாட்சி',
#  'மின்காந்தவியலில்மேற்பரப்பொன்றினூடாகப்',
#  'வெளியிடப்பட்டிருக்கிறதுவிபரப்பட்டியல்',
#  'காணப்பட்டுள்ளதுர்கத்உல்ிகாதிஅல்இ்லாமி',
#  'பிரிவில்செயலாட்சியர்அன்ட்டார்ட்டிக்கா',
#  'மார்க்கங்களாகும்அவு்விட்்பிர்க்கெனாவு',
#  'சிவத்தலமாகும்மேலைத்திருப்பூந்துருத்தி',
#  'முன்னெடுக்கப்படுகின்றதுசிற்பநூல்களில்',
#  'பணியாற்றியிருக்கிறார்சுந்தரப்பெருமாள்',
#  'கோழிக்கோடுமஞ்சேரிமலைப்புறம்நீலாம்பூர்',
#  'தேர்ந்தெடுக்கப்பட்டுள்ளார்சோமநாதபுரம்',
#  'பங்காளியாகும்பாலிகலக்டோயுறேனசுமரபணுத்',
#  'நியமிக்கப்படுகின்றனர்தமிழ்நாட்டிலுள்ள',
#  'சொல்லாகப்பயன்படுத்தப்படுகின்றதுசாஞ்சி',
#  'நிர்ணயிக்கப்பட்டுள்ளதுவேதிப்பொருட்கள்',
#  'திரைப்படமாகும்பண்டாரநாயக்கசெல்வநாயகம்',
#  'நடித்திருந்தனர்கணினிப்பயன்பாட்டுக்கான',
#  'பிரகடனப்படுத்தப்பட்டிருக்கலாம்உடலும்',
#  'நங்கைநல்லூர்பழவந்தாங்கல்தலக்கனன்சேரி',
#  'பாராட்டப்படுவதுண்டுஆடம்பரப்பண்டங்கள்',
#  'குறிப்பிடப்பட்டுள்ளதுஅலைவழிப்படுத்தி',
#  'செய்யப்படுகிறதுசெயலாட்சியர்பக்ருதின்',
#  'பணியமர்த்தப்படுகின்றனர்பல்கலைக்கழகம்',
#  'பட்டியலிடப்படுகின்றனபொதுமக்களுக்குத்',
#  'நிர்மாணிக்கப்பட்டிருக்கும்வல்லவரையன்',
#  'குறிப்பிடத்தக்கதுபிறபண்பாட்டுமயமாதல்',
#  'அமையப்பெற்றிருக்கதிருமுருகாற்றுப்படை',
#  'குறிப்பிடப்பட்டுள்ளதுகட்டிடக்கலையில்',
#  'முயல்கிறதுமுத்தேவியர்இணைப்புப்பண்டம்',
#  'பிரகடனப்படுத்தப்பட்டுள்ளதுசியார்சியா',
#  'பணியமர்த்தப்பட்டுள்ளனர்தமிழ்நாட்டில்',
#  'பிரதிநிதித்துவப்படுத்துவதாகும்சமையல்',
#  'தேர்ந்தெடுக்கப்படுகிறார்கள்பொறியியல்',
#  'விளைவிக்கப்படுகிறதுஉருவகப்படுத்துதல்',
#  'கண்டுபிடிக்கப்பட்டதுடன்தொடங்குகிறது',
#  'சுட்டிக்காட்டியுள்ளார்கள்இந்து்தானி',
#  'இத்திரைப்படத்தில்ெய்சங்கர்்ரீபிரியா',
#  'தன்மாத்திரைகளாகும்இத்தன்மாத்திரைகள்',
#  'மறைக்கப்படுகின்றதுஒன்றுக்குமேற்பட்ட',
#  'அழைக்கப்படுகிறதுபர்ன்ைட்ஃப்ரொபீனிய்',
#  'நாட்டுடைமையாக்கப்பட்டுள்ளனஒட்டுண்ணி',
#  'பதவிப்பெயர்2ஆணையர்சுந்தரபாண்டிபுரம்',
#  'நடைமுறைப்படுத்தப்படும்முடக்கொத்தான்',
#  'கண்டெடுக்கப்பட்டுள்ளனசிக்குன்குனியா',
#  'கண்டுபிடிக்கப்பட்டதுஇடாய்ச்சுலாந்து',
#  'உபயோகப்படுத்தப்படுகிறதுகருவிப்பட்டை',
#  'முன்வைத்திருக்கின்றதுஎதிர்மின்னிகளை',
#  'குறிப்பிடப்படுகிறதுசிந்தாரிப்பேட்டை',
#  'தெரிவுசெய்யப்பட்டிருந்தார்சண்டேசுவர',
#  'இன்றைப்படுத்தப்படும்கிளைப்பாட்டியல்',
#  'வகைப்படுத்தப்பட்டுள்ளதுபெரும்பாலும்',
#  'வழங்கப்படுகின்றனதீங்குயிர்கொல்லிகள்',
#  'ஆரம்பிக்கப்பட்டதுகணினியியியலுக்குக்',
#  'அழைக்கப்படுகின்றதுவார்ப்புருபூநாடி',
#  'ஈஎ்பிஎன்கிரிக்கின்போதற்குறிப்பேற்ற',
#  'கிரிக்கெட்ஆர்க்கைவ்வடிவமைக்கப்பட்ட',
#  'அறிமுகப்படுத்தியதுதிருக்கண்டீ்வரம்',
#  'சிவத்தலமாகும்திருநாட்டியத்தான்குடி',
#  'பயன்படுத்தப்படுகிறதுஒட்டுண்ணியியல்',
#  'கொடுக்கப்பட்டுள்ளதுட்விதமார்க்கிணி',
#  'மொழிபெயர்க்கப்பட்டுள்ளனமார்க்சியம்',
#  'அழைக்கப்பட்டிருந்ததுமணிகண்டீசுவரர்',
#  'பார்க்கவும்செயலாட்சியர்கிளிக்எழுதி',
#  'நீக்கப்பட்டுவிட்டதுதிருவிடைமருதூர்',
#  'வடிவமைக்கப்பட்டுள்ளதுமூர்ச்சனாகாரக',
#  'புரிந்துகொள்ளப்படுகிறதுசர்க்காரியா',
#  'பெறப்பட்டுள்ளனபிடிஆர்பழனிவேல்ராசன்',
#  'முதலீட்டாளர்களுக்குமுகாமையாளருக்கு',
#  'இராச்சியத்தின்பொறுப்பாகும்பிரெஞ்சு',
#  'சமயமாகும்முத்தேவியர்மின்காந்தவியல்',
#  'பயன்படுத்தப்பட்டுள்ளதுஉயிர்ச்சத்து',
#  'இத்திரைப்படத்தில்்ரீகாந்த்சுமித்ரா',
#  'குறிப்பிடத்தக்கதுஇத்திரைப்படத்தில்',
#  'எடுத்துக்காட்டுகளாகும்நிக்காட்டீன்',
#  'தேர்ந்தெடுக்கப்பட்டுள்ளார்கனகசூரிய',
#  'பயன்படுத்தப்படுகின்றதுிப்ரால்ட்டர்',
#  'கண்டுபிடிக்கப்படவில்லைசுவர்ப்பந்து',
#  'இடைநிறுத்தினார்பொன்னம்பலவாணேசுவரர்',
#  'அமைந்துள்ளதுவார்ப்புருஇருவாழ்விகள்',
#  'வடிவமைக்கப்பட்டிருக்கும்அர்ென்டீனா',
#  'அமைந்துள்ளதுமேலத்திருப்பந்துருத்தி',
#  'நிருவகிக்கப்படுகிறதுமைக்கொசெப்பரசு',
#  'பட்டியலிடப்படுகின்றனபிறப்பொலியியல்',
#  'வெளியிட்டுள்ளார்அம்மாவாரிக்குப்பம்',
#  'உருவாக்கப்பட்டதுஎழுத்துப்பெயர்ப்பு',
#  'திருமங்கையாழ்வார்திருமழிசையாழ்வார்',
#  'விவரிக்கிறதுபுன்னத்தூர்கோட்டைபியு்',
#  'உருவாக்குவதில்லைகரும்பருந்துஅல்லது',
#  'குறிக்கப்படுவதுண்டுஒழுங்குபடுத்தல்',
#  'கண்டுபிடிக்கப்பட்டதுகார்பெண்டாரியா',
#  'முடிகிறதுசெயலாட்சியர்திருநெல்வேலி',
#  'அகழ்ந்தெடுக்கப்படுகிறதுசெப்டம்பர்',
#  'பயன்படுத்தப்படுகிறதுசூழ்பொருளியல்',
#  'எதிர்பார்க்கப்படுகின்றதுஇதயத்தில்',
#  'வெளியேறியிருக்கிறார்இரண்டாயிரத்து',
#  'திகழ்ந்துவருகின்றதுராகச்சந்திரிகா',
#  'பயன்படுத்தப்பட்டனதிருக்கேதீச்சரம்',
#  'அறிவிக்கப்பட்டுள்ளதுமின்சாரத்தைப்',
#  'தரப்படுத்தப்பட்டுள்ளதுதிருநாவலூர்',
#  'பயன்படுகின்றதுஒப்பந்தச்சட்டத்தில்',
#  'பிரித்தெடுக்கப்படுகிறதுஇலங்கையின்',
#  'அறியப்பட்டதுயூபிக்கியுட்டினேற்றம்',
#  'அரசியலுக்கும்எம்ிஇராமச்சந்திரனால்',
#  'அவசியமானவைசெயலாட்சியர்கட்டுரையில்',
#  'வனமுலையம்மன்திருச்செங்காட்டங்குடி',
#  'ஆவணப்படுத்தப்பட்டுள்ளதுஒண்டிவீரன்',
#  'காணமுடியும்மாழைஆக்ைடுகுறைக்கடத்தி',
#  'பயன்படுத்துகிறார்கள்தமிழ்நாட்டில்',
#  'அங்கீகரிக்கப்பட்டுள்ளனஇந்தியாவின்',
#  'சித்தரிக்கப்படுபவர்கள்பௌத்தத்தில்',
#  'பயன்படுத்தப்படுகின்றதுவெவ்வேறுவகை',
#  'இடம்பெற்றிருந்தனவண்ணாத்திக்குருவி',
#  'எடுத்துக்கொள்ளப்படுகிறதுபுரட்டாசி',
#  'பிரதிபடுத்துகின்றனசிந்துவெளிரப்பா',
#  'பணியாற்றியவனாவான்மழவச்சக்ரவர்த்தி',
#  'எடுத்துக்காட்டுகள்காவக்காரப்பட்டி',
#  'இசுட்ரிக்கோமார்ப்பாகேவியோமார்ப்பா',
#  'அழைக்கப்பட்டிருக்கின்றதுஎழுவைதீவு',
#  'நிறுத்தப்பட்டுவிட்டதுதிருவண்ணாமலை',
#  'மேம்படுத்தப்படக்கூடியவைமருத்துவர்',
#  'குறிப்பிடப்படுவதுண்டுசெல்வநிாந்த்',
#  'குறிப்பிடப்பட்டிருந்ததுபக்கசார்பு',
#  'அழைக்கப்படுகின்றனதமிழ்நாட்டிலுள்ள',
#  'தீண்டாமைக்குட்படுத்தப்படுகின்றனர்',
#  'அமைத்தார்கள்முத்தேவியர்காஞ்சீவரம்',
#  'அறிமுகப்படுத்தப்பட்டதுசோழநாட்டிலே',
#  'பயன்படுத்துகின்றனர்ஆவணங்களுக்கும்',
#  'அடையாளமிடப்படுகின்றனசெஇராமலிங்கம்',
#  'பயன்படுத்தப்படுகிறதுசுதந்திரவாதம்',
#  'தேர்ந்தெடுக்கப்பட்டார்சூபித்துவம்',
#  'அழைக்கப்படுகின்றனர்சித்திரகுப்தர்',
#  'பரிந்துரைக்கப்பட்டுள்ளனர்கா்பேக்ி',
#  'பல்கலைக்கழகம்பெர்க்லேகலிஃபோர்னியா',
#  'பயன்படுத்தப்படுகின்றனநார்ப்புரதம்',
#  'மேற்கொள்ளப்படுகின்றனவிண்மீன்களைக்',
#  'மொழிபெயர்க்கப்பட்டுள்ளதுஇந்திரித்',
#  'உருவாக்கியவர்உயிர்க்கோளத்திற்கும்',
#  'கருதப்படுகிறார்கள்அரிசுட்டாட்டில்',
#  'உயர்த்தப்பட்டதுஎசுக்காண்டினாவியா',
#  'அடக்கிக்கொண்டதுகண்ணியத்திற்குரிய',
#  'பயன்படுத்தினர்கோபாலகிரு்ணன்இதயம்',
#  'அங்கீகரித்துள்ளனதமிழ்நாட்டிலுள்ள',
#  'அமைந்துள்ளதுமுக்குடிவேலம்பாளையம்',
#  'ஒழுங்கமைக்கப்பட்டிருக்கும்பொழுது',
#  'இலக்கியவாதியுமாவார்காலுதைச்சண்டை',
#  'காணலாம்இலக்குகள்நாகலிங்கம்பிள்ளை',
#  'குற்றஞ்சாட்டப்பட்டவர்இந்தியாவில்',
#  'நிர்ணயிக்கப்பட்டதுகின்னரப்பெட்டி',
#  'குறிப்பிடப்படுவதுண்டுயாழ்ப்பாணப்',
#  'நடைமுறைப்படுத்தப்படுகிறதுதமிழ்ப்',
#  'அழைக்கப்படுகின்றனர்அந்துவஞ்சேரல்',
#  'பணியமர்த்தப்படுகின்றனர்வியகுமாரி',
#  'திருக்கோயில்திருப்பள்ளிமுக்கூடல்',
#  'அச்சுறுத்தலுக்குள்ளாகியிருக்கும்',
#  'பட்டியலிடப்படுகின்றனபொம்மலாட்டம்',
#  'பயிற்றுவிக்கப்படுகின்றனகொ்கிய்கோ',
#  'குறிப்பிடப்பட்டுள்ளதுநந்திவர்மன்']

# %%
a=sorted_uniq_words[14]
